# %%
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/Hank/Project/Python_Udemy

# %%
stats = pd.read_csv('/Users/Hank/Project/Python_Udemy/DemographicData.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %% [markdown]
# ---

# %%
# Exploring Your Data

# %%
# 1. Full Dataframe
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
# 2. Number of Rows
len(stats)# 195 rows imported
# Out:
# 195

# %%
# 3. See Columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
# 4. Number of Columns
len(stats.columns)
# Out:
# 5

# %%
# 5. Top Rows
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(7)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
# 6.Bottom Rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.tail(7)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 188  West Bank and Gaza          PSE      30.394            46.6
# 189               Samoa          WSM      26.172            15.3
# 190         Yemen, Rep.          YEM      32.947            20.0
# 191        South Africa          ZAF      20.850            46.5
# 192    Congo, Dem. Rep.          COD      42.394             2.2
# 193              Zambia          ZMB      40.471            15.4
# 194            Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# 7. Information on the Columns
stats.info() #like the str() in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# 8. Get the Stats on the Columns
stats.describe() #get stats information of all your numeric columns 
                 #like summary() in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
#Transposed
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# ---

# %%
#Renaming Columns of DataFrame

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['a', '2', 'r', 't', '7']

# %%
stats.head()
# Out:
#                       a    2       r     t                    7
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %%
#Subsetting Dataframes in Pandas

# %%
# 1. Rows

# %%
stats[23:28]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 23            Bolivia         BOL     24.236          36.94
# 24             Brazil         BRA     14.931          51.04
# 25           Barbados         BRB     12.188          73.00
# 26  Brunei Darussalam         BRN     16.405          64.50
# 27             Bhutan         BTN     18.134          29.90
#
#             IncomeGroup
# 23  Lower middle income
# 24  Upper middle income
# 25          High income
# 26          High income
# 27  Lower middle income

# %%
#Since the way of most of peple use tables and dataframes or datasets is have the name of columns at the top,
#and then you have data going down, so every row is a new entry of data,
#so it's already biased in that sense, which means Python knows when we are more likely to slice data by rows

# %%
stats[:7]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[190:]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# Reverse the Dataframe

# %%
stats[::-1]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 194                        Zimbabwe         ZWE     35.715       18.50000
# 193                          Zambia         ZMB     40.471       15.40000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 191                    South Africa         ZAF     20.850       46.50000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 189                           Samoa         WSM     26.172       15.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 187                         Vanuatu         VUT     26.739       11.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# ...

# %%
# Get Only 20th Rows

# %%
stats[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
# 2. Columns

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
# extract by columns
# example: extract only column BirthRate
stats['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
# 5      17.716
# 6      13.308
# 7      16.447
# 8      13.200
# 9       9.400
# 10     18.300
# 11     44.151
# 12     11.200
# 13     36.440
# 14     40.551
# 15     20.142
# 16      9.200
# 17     15.040
# 18     15.339
# 19      9.062
# 20     12.500
# 21     23.092
# 22     10.400
# 23     24.236
# 24     14.931
# 25     12.188
# 26     16.405
# 27     18.134
# 28     25.267
# 29     34.076
#         ...
# 165    18.600
# 166    24.043
# 167    45.745
# 168    36.080
# 169    11.041
# 170    30.792
# 171    21.322
# 172    35.755
# 173    25.409
# 174    14.590
# 175    19.800
# 176    16.836
# 177    39.518
# 178    43.474
# 179    11.100
# 180    14.374
# 181    12.500
# 182    22.500
# 183    16.306
# 184    19.842
# 185    10.700
# 186    15.537
# 187    26.739
# 188    30.394
# 189    26.172
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# ...

# %%
stats['BirthRate'].head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
# extracting 2 or more columns
['BirthRate', 'IncomeGroup']
stats[['BirthRate', 'IncomeGroup']] # need to be input as a list
# Out:
#      BirthRate          IncomeGroup
# 0       10.244          High income
# 1       35.253           Low income
# 2       45.985  Upper middle income
# 3       12.877  Upper middle income
# 4       11.044          High income
# 5       17.716          High income
# 6       13.308  Lower middle income
# 7       16.447          High income
# 8       13.200          High income
# 9        9.400          High income
# 10      18.300  Upper middle income
# 11      44.151           Low income
# 12      11.200          High income
# 13      36.440           Low income
# 14      40.551           Low income
# 15      20.142  Lower middle income
# 16       9.200  Upper middle income
# 17      15.040          High income
# 18      15.339          High income
# 19       9.062  Upper middle income
# 20      12.500  Upper middle income
# 21      23.092  Upper middle income
# 22      10.400          High income
# 23      24.236  Lower middle income
# 24      14.931  Upper middle income
# ...

# %%
stats[['IncomeGroup', 'BirthRate']].head() # they do follow the order you specified
# Out:
#            IncomeGroup  BirthRate
# 0          High income     10.244
# 1           Low income     35.253
# 2  Upper middle income     45.985
# 3  Upper middle income     12.877
# 4          High income     11.044

# %%
#Quick Access

# %%
stats.BirthRate.head()#Quick access required for one word, 
                      #also why we need to keep columns name in our data frame neat at the first place.
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
#3. How to Combine Those Two Together

# %%
stats[5:9][['BirthRate', 'IncomeGroup']]
# Out:
#    BirthRate          IncomeGroup
# 5     17.716          High income
# 6     13.308  Lower middle income
# 7     16.447          High income
# 8     13.200          High income

# %%
stats[['BirthRate', 'IncomeGroup']][5:9]
# Out:
#    BirthRate          IncomeGroup
# 5     17.716          High income
# 6     13.308  Lower middle income
# 7     16.447          High income
# 8     13.200          High income

# %% [markdown]
# ---

# %%
# Basic Operation With Dataframes

# %%
# Mathematical Operations:
results = stats.BirthRate * stats.InternetUsers

# %%
results.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
results
# Out:
# 0       808.251600
# 1       207.992700
# 2       878.313500
# 3       736.564400
# 4       971.872000
# 5      1061.188400
# 6       557.605200
# 7      1042.739800
# 8      1095.600000
# 9       757.816720
# 10     1074.210000
# 11       57.396300
# 12      920.306240
# 13      178.556000
# 14      369.014100
# 15      133.541460
# 16      488.165800
# 17     1353.600597
# 18     1104.408000
# 19      523.692980
# 20      677.125000
# 21      775.891200
# 22      991.120000
# 23      895.277840
# 24      762.078240
# 25      889.724000
# 26     1058.122500
# 27      542.206600
# 28      379.005000
# 29      119.266000
#           ...
# 165     937.440000
# 166     629.926600
# 167     105.213500
# 168     162.360000
# 169     319.526540
# 170     492.672000
# 171     204.691200
# 172      39.330500
# 173     889.315000
# 174     930.842000
# 175     867.240000
# 176     778.665000
# 177     173.879200
# 178     704.278800
# 179     455.100000
# 180     829.236060
# ...

# %%
type(results)
# Out:
# pandas.core.series.Series

# %%
#Add Column

# %%
stats['Mycolm'] = stats.BirthRate * stats.InternetUsers

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    Mycolm
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
#Remove the column

# %%
stats.drop('Mycolm', 1) #need to specify '1', so the function can work on columns
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
stats = stats.drop('Mycolm', 1) # drop() won't save the new dataframe in the original,
                               #need to re-save in the original obj

# %% [markdown]
# ---

# %%
# Filtering DataFrames

# %%
#filtering is about rows

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.InternetUsers<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter1 = stats.InternetUsers<2

# %%
stats[Filter1]# it will only list out where the filter1's holding True
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
Filter2 = stats.BirthRate > 40

# %%
stats[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats[Filter1 & Filter2]# we cannot use 'and' here, 
                        # cause by default, this 'and' means it is trying to work with 2 single value,
                        # so it is saying that this 'and' is waiting, 
                        # and it's expecting for a single true or false from both side.
                        # but it doesn't know how to work with list or other objects.
                        # '&' this is bitwise, ampersand.
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
#another example
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats.IncomeGroup == "High income"]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244       78.90000  High income
# 4     United Arab Emirates         ARE     11.044       88.00000  High income
# 5                Argentina         ARG     17.716       59.90000  High income
# 7      Antigua and Barbuda         ATG     16.447       63.40000  High income
# 8                Australia         AUS     13.200       83.00000  High income
# 9                  Austria         AUT      9.400       80.61880  High income
# 12                 Belgium         BEL     11.200       82.17020  High income
# 17                 Bahrain         BHR     15.040       90.00004  High income
# 18            Bahamas, The         BHS     15.339       72.00000  High income
# 22                 Bermuda         BMU     10.400       95.30000  High income
# 25                Barbados         BRB     12.188       73.00000  High income
# ...

# %%
# how to get the unique categories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# quick exercise
# find out everything about Malta
stats[stats.CountryName == "Malta"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %% [markdown]
# ---

# %%
#Accessing Individual Elements

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#.at[]  # for labels, important: even integers are treated as labels
#.iat[] # for integer location

# %%
stats.iat[3, 4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0, 3]
# Out:
# 78.9

# %%
stats.at[0, 'CountryCode']
# Out:
# 'ABW'

# %%
# why we need .at[]

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10, 'CountryName']
# Out:
# 'Azerbaijan'

# %% [markdown]
# ---

# %%
# Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=8,4

# %%
# what seaborn does is it actually just makes obvious solutions better, it gives us more awesome functions.
# but at the end of the day it still uses matplotlib.
# it's kind of like a upgrade on top of matplotlib.

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Distribution:
vis1 = sns.distplot(stats['InternetUsers'])

# %%
vis1 = sns.distplot(stats['InternetUsers'], bins = 30)

# %%
vis1 = sns.distplot(stats['InternetUsers'], bins = 15)

# %%
# Boxplots
vis2 = sns.boxplot(data=stats, x='IncomeGroup', y='BirthRate')

# %%
# go check out Seaborn Gallery

# %% [markdown]
# ---

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg = False)

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',
                  fit_reg = False, hue = 'IncomeGroup')

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',
                  fit_reg = False, hue = 'IncomeGroup', size = 10)

# %%
# keyword Arguments in Python

# %%
# marker size:
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',
                  fit_reg = False, hue = 'IncomeGroup', size = 10,
                 scatter_kws = {'s':150})

# %% [markdown]
# ---

# %%
Country_Code = list (["ABW","AFG","AGO","ALB","ARE","ARG","ARM","ATG","AUS","AUT","AZE","BDI","BEL","BEN","BFA","BGD","BGR","BHR","BHS","BIH","BLR","BLZ","BOL","BRA","BRB","BRN","BTN","BWA","CAF","CAN","CHE","CHL","CHN","CIV","CMR","COG","COL","COM","CPV","CRI","CUB","CYP","CZE","DEU","DJI","DNK","DOM","DZA","ECU","EGY","ERI","ESP","EST","ETH","FIN","FJI","FRA","FSM","GAB","GBR","GEO","GHA","GIN","GMB","GNB","GNQ","GRC","GRD","GTM","GUM","GUY","HKG","HND","HRV","HTI","HUN","IDN","IND","IRL","IRN","IRQ","ISL","ITA","JAM","JOR","JPN","KAZ","KEN","KGZ","KHM","KIR","KOR","KWT","LAO","LBN","LBR","LBY","LCA","LKA","LSO","LTU","LUX","LVA","MAC","MAR","MDA","MDG","MDV","MEX","MKD","MLI","MLT","MMR","MNE","MNG","MOZ","MRT","MUS","MWI","MYS","NAM","NCL","NER","NGA","NIC","NLD","NOR","NPL","NZL","OMN","PAK","PAN","PER","PHL","PNG","POL","PRI","PRT","PRY","PYF","QAT","ROU","RUS","RWA","SAU","SDN","SEN","SGP","SLB","SLE","SLV","SOM","SSD","STP","SUR","SVK","SVN","SWE","SWZ","SYR","TCD","TGO","THA","TJK","TKM","TLS","TON","TTO","TUN","TUR","TZA","UGA","UKR","URY","USA","UZB","VCT","VEN","VIR","VNM","VUT","WSM","YEM","ZAF","COD","ZMB","ZWE"])
# %%
import numpy as np
Expect = pd.DataFrame({'CountryCode': np.array(Country_Code), 
                       'LEB1960': np.array(Life_Expectancy_At_Birth_1960), 
                       'LEB2013': np.array(Life_Expectancy_At_Birth_2013)})

# %%
Expect
# Out:
#     CountryCode    LEB1960    LEB2013
# 0           ABW  65.569366  75.328659
# 1           AFG  32.328512  60.028268
# 2           AGO  32.984829  51.866171
# 3           ALB  62.254366  77.537244
# 4           ARE  52.243220  77.195634
# 5           ARG  65.215537  75.986098
# 6           ARM  65.863463  74.561366
# 7           ATG  61.782732  75.778659
# 8           AUS  70.817073  82.197561
# 9           AUT  68.585610  80.890244
# 10          AZE  60.836244  70.693146
# 11          BDI  41.236049  56.251610
# 12          BEL  69.701951  80.385366
# 13          BEN  37.278268  59.312024
# 14          BFA  34.477902  58.240634
# 15          BGD  45.829317  71.245244
# 16          BGR  69.247561  74.465854
# 17          BHR  52.089366  76.545951
# 18          BHS  62.729049  75.073537
# 19          BIH  60.276220  76.276927
# 20          BLR  67.708098  72.470732
# 21          BLZ  59.961366  69.982049
# 22          BOL  42.118317  67.913439
# 23          BRA  54.205463  74.122439
# ...

# %%
m_stats=pd.merge(left=stats, right=Expect, on='CountryCode')

# %%
Countries_2012_Dataset = list (["Aruba","Afghanistan","Angola","Albania","United Arab Emirates","Argentina","Armenia","Antigua and Barbuda","Australia","Austria","Azerbaijan","Burundi","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Bahamas, The","Bosnia and Herzegovina","Belarus","Belize","Bermuda","Bolivia","Brazil","Barbados","Brunei Darussalam","Bhutan","Botswana","Central African Republic","Canada","Switzerland","Chile","China","Cote d'Ivoire","Cameroon","Congo, Rep.","Colombia","Comoros","Cabo Verde","Costa Rica","Cuba","Cayman Islands","Cyprus","Czech Republic","Germany","Djibouti","Denmark","Dominican Republic","Algeria","Ecuador","Egypt, Arab Rep.","Eritrea","Spain","Estonia","Ethiopia","Finland","Fiji","France","Micronesia, Fed. Sts.","Gabon","United Kingdom","Georgia","Ghana","Guinea","Gambia, The","Guinea-Bissau","Equatorial Guinea","Greece","Grenada","Greenland","Guatemala","Guam","Guyana","Hong Kong SAR, China","Honduras","Croatia","Haiti","Hungary","Indonesia","India","Ireland","Iran, Islamic Rep.","Iraq","Iceland","Israel","Italy","Jamaica","Jordan","Japan","Kazakhstan","Kenya","Kyrgyz Republic","Cambodia","Kiribati","Korea, Rep.","Kuwait","Lao PDR","Lebanon","Liberia","Libya","St. Lucia","Liechtenstein","Sri Lanka","Lesotho","Lithuania","Luxembourg","Latvia","Macao SAR, China","Morocco","Moldova","Madagascar","Maldives","Mexico","Macedonia, FYR","Mali","Malta","Myanmar","
Regions_2012_Dataset = list (["The Americas","Asia","Africa","Europe","Middle East","The Americas","Asia","The Americas","Oceania","Europe","Asia","Africa","Europe","Africa","Africa","Asia","Europe","Middle East","The Americas","Europe","Europe","The Americas","The Americas","The Americas","The Americas","The Americas","Asia","Asia","Africa","Africa","The Americas","Europe","The Americas","Asia","Africa","Africa","Africa","The Americas","Africa","Africa","The Americas","The Americas","The Americas","Europe","Europe","Europe","Africa","Europe","The Americas","Africa","The Americas","Africa","Africa","Europe","Europe","Africa","Europe","Oceania","Europe","Oceania","Africa","Europe","Asia","Africa","Africa","Africa","Africa","Africa","Europe","The Americas","The Americas","The Americas","Oceania","The Americas","Asia","The Americas","Europe","The Americas","Europe","Asia","Asia","Europe","Middle East","Middle East","Europe","Middle East","Europe","The Americas","Middle East","Asia","Asia","Africa","Asia","Asia","Oceania","Asia","Middle East","Asia","Middle East","Africa","Africa","The Americas","Europe","Asia","Africa","Europe","Europe","Europe","Asia","Africa","Europe","Africa","Asia","The Americas","Europe","Africa","Europe","Asia","Europe","Asia","Africa","Africa","Africa","Africa","Asia","Africa","Oceania","Africa","Africa","The Americas","Europe","Europe","Asia","Oceania","Middle East","Asia","The Americas","The Americas","Asia","Oceania","Europe","The Americas","Europe","The Americas","Oceania","Middle East","Europe","Europe","Africa","Middle East","Africa","Africa","Asia","Oceania","Africa","The Americas","Africa","Europe","Africa","Africa","The Americas","Europe","Europe","Europe","Africa","Africa","Middle East","Africa","Africa","Asia","Asia","Asia","Asia","Oceania","The Americas","Africa","Europe","Africa","Africa","Europe","The Americas","The Americas","Asia","The Americas","The Americas","The Americas","Asia","Oceania","Middle East","Oceania","Middle East","Africa","Africa","Africa","Africa"])

# %%
countries2012 = pd.DataFrame({                              'CountryCode':np.array(Codes_2012_Dataset),
                             'Regions': np.array(Regions_2012_Dataset)})

# %%
countries2012
# Out:
#     CountryCode       Regions
# 0           ABW  The Americas
# 1           AFG          Asia
# 2           AGO        Africa
# 3           ALB        Europe
# 4           ARE   Middle East
# 5           ARG  The Americas
# 6           ARM          Asia
# 7           ATG  The Americas
# 8           AUS       Oceania
# 9           AUT        Europe
# 10          AZE          Asia
# 11          BDI        Africa
# 12          BEL        Europe
# 13          BEN        Africa
# 14          BFA        Africa
# 15          BGD          Asia
# 16          BGR        Europe
# 17          BHR   Middle East
# 18          BHS  The Americas
# 19          BIH        Europe
# 20          BLR        Europe
# 21          BLZ  The Americas
# 22          BMU  The Americas
# 23          BOL  The Americas
# 24          BRA  The Americas
# 25          BRB  The Americas
# 26          BRN          Asia
# 27          BTN          Asia
# 28          BWA        Africa
# 29          CAF        Africa
# ...

# %%
mr_stats=pd.merge(left=m_stats, right=countries2012, on='CountryCode')

# %%
mr_stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    LEB1960    LEB2013       Regions
# 0          High income  65.569366  75.328659  The Americas
# 1           Low income  32.328512  60.028268          Asia
# 2  Upper middle income  32.984829  51.866171        Africa
# 3  Upper middle income  62.254366  77.537244        Europe
# 4          High income  52.243220  77.195634   Middle East

# %%
vis4 = sns.lmplot(data = mr_stats, x='BirthRate', y='LEB1960', hue='Regions', fit_reg = False)

# %%
vis4 = sns.lmplot(data = mr_stats, x='BirthRate', y='LEB2013', hue='CountryName', fit_reg = False)
